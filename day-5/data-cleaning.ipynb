# %% [markdown]
# # Day 5: Data Cleaning
#
# This notebook is for cleaning the `products.csv` dataset.

# %%
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv('products.csv')
df.head()
